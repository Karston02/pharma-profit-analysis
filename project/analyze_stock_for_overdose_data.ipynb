# %%
# import libraries
import pandas as pd

# %% [markdown]
# #### Read symbols into respective dataframes

# %%
# list of tickers we have data for in pkl file
tickers = ['LLY', 'NVO', 'JNJ', 'MRK', 'ABBV', 'MRNA',
           'NVS', 'AZN', 'PFE', 'AMGN', 'PPH', 'IHE', 'PJP']

dfs = {}  # dictionary to store all dataframes

for symbol in tickers:
    # for each symbol, load the pkl file and store it in the dictionary as a df
    dfs[f"{symbol}_df"] = pd.read_pickle(f"pharma-data/raw-data/stocks-for-overdose/{symbol}.pkl")

# %% [markdown]
# #### Sanity Check
# ##### Check all the df.head() to ensure they worked

# %% [markdown]
# #### Check for null values

# %%
# print all null values in each dataframe
for df in dfs:
    print(f"Null values in {df}")
    print(dfs[df].isnull().sum())
    print("\n")

# we see there are no null values anywhere. yfinance dealt with them.
# Out:
# Null values in LLY_df
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
#
#
# Null values in NVO_df
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
#
#
# Null values in JNJ_df
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
#
#
# Null values in MRK_df
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
#
#
# Null values in ABBV_df
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
#
#
# Null values in MRNA_df
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
#
#
# Null values in NVS_df
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
#
#
# Null values in AZN_df
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
#
#
# Null values in PFE_df
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
#
#
# Null values in AMGN_df
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
#
#
# Null values in PPH_df
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
#
#
# Null values in IHE_df
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
#
#
# Null values in PJP_df
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
# check example of shape
dfs['LLY_df'].shape
# Out:
# (3000, 6)

# %%
# find statistics (range, median, mean, std) for all quantitative columns
for df_name, df in dfs.items():
    # Selecting quantitative columns
    quantitative_cols = ['Open', 'High', 'Low', 'Close', 'Volume']
    quantitative_cols = [col for col in quantitative_cols if col in df.columns]

    print(f"Statistics for {df_name}:")
    print(df[quantitative_cols].describe())
    print("\n")
# Out:
# Statistics for LLY_df:
#               Open         High          Low        Close        Volume
# count  3000.000000  3000.000000  3000.000000  3000.000000  3.000000e+03
# mean    154.850007   156.551967   153.205803   154.960610  4.552904e+06
# std     139.272646   140.997428   137.541626   139.385318  4.281182e+06
# min      39.279999    39.599998    39.160000    39.180000  6.272000e+05
# 25%      71.152502    71.767500    70.414999    71.224998  2.765400e+06
# 50%      85.900002    86.485001    85.240002    85.939999  3.680200e+06
# 75%     190.102501   192.087498   188.095005   190.650002  5.063950e+06
# max     790.000000   794.469971   769.119995   782.059998  7.482250e+07
#
#
# Statistics for NVO_df:
#               Open         High          Low        Close        Volume
# count  3000.000000  3000.000000  3000.000000  3000.000000  3.000000e+03
# mean     34.134067    34.392269    33.887149    34.156773  3.220037e+06
# std      21.522346    21.739242    21.347328    21.571745  2.297689e+06
# min      13.008000    13.125000    12.941000    13.075000  3.886000e+05
# 25%      21.778750    21.915001    21.653750    21.788751  1.916750e+06
# 50%      25.930000    26.125000    25.740000    25.922500  2.568200e+06
# 75%      35.977501    36.126249    35.695000    35.897499  3.747100e+06
# max     124.620003   124.870003   123.010002   124.519997  2.885700e+07
#
#
# Statistics for JNJ_df:
#               Open         High          Low        Close        Volume
# count  3000.000000  3000.000000  3000.000000  3000.000000  3.000000e+03
# mean    127.332070   128.202287   126.433340   127.352087  8.154425e+06
# std      31.384677    31.662667    31.094437    31.378780  6.067190e+06
# min      62.040001    62.310001    61.709999    61.779999  2.114900e+06
# 25%     101.239998   101.867502   100.587498   101.227503  5.726250e+06
# 50%     130.860001   131.659996   129.709999   130.715004  7.056250e+06
# 75%     153.979996   155.107506   152.635006   153.997505  9.054125e+06
# max     185.100006   186.690002   184.179993   186.009995  1.513195e+08
#
#
# Statistics for MRK_df:
#               Open         High          Low        Close        Volume
# count  3000.000000  3000.000000  3000.000000  3000.000000  3.000000e+03
# mean
df:
#               Open         High          Low        Close        Volume
# count  3000.000000  3000.000000  3000.000000  3000.000000  3.000000e+03
# mean    182.029003   183.835960   180.164117   182.049930  3.231432e+06
# std      55.420008    55.944292    54.840983    55.407350  1.663653e+06
# min      65.589996    66.330002    65.370003    65.589996  6.128000e+05
# 25%     149.102501   151.202503   147.190006   149.285004  2.262150e+06
# 50%     178.025002   180.324997   176.669998   178.330002  2.823250e+06
# 75%     230.180004   232.192501   227.717506   229.867504  3.740700e+06
# max     325.399994   329.720001   320.750000   324.559998  2.393680e+07
#
#
# Statistics for PPH_df:
#               Open         High          Low        Close        Volume
# count  3000.000000  3000.000000  3000.000000  3000.000000  3.000000e+03
# mean     62.165163    62.488283    61.806740    62.168033  8.932413e+04
# std      11.157320    11.210209    11.101842    11.161176  1.666701e+05
# min      36.189999    36.439999    36.049999    36.220001  2.900000e+03
# 25%      56.517500    56.827501    56.077501    56.459999  2.260000e+04
# 50%      61.195000    61.555000    60.855000    61.200001  4.455000e+04
# 75%      71.482502    71.772497    70.980003    71.410004  9.850000e+04
# max      90.870003    90.930000    90.290001    90.589996  3.472000e+06
#
#
# Statistics for IHE_df:
#               Open         High          Low        Close         Volume
# count  3000.000000  3000.000000  3000.000000  3000.000000    3000.000000
# mean    151.895697   152.748540   150.905750   151.876657   25824.566667
# std      29.783753    29.916082    29.668191    29.791529   43537.417111
# min      79.669998    80.050003    79.150002    79.500000    1200.000000
# 25%     139.859997   140.880005   138.557499   139.764996    6375.000000
# 50%     153.775002   154.575005   152.600006   153.724998   13500.000000
# 75%     176.000000   177.117500   175.195004   176.112499   28300.000000
# max     208.119995   208.679993   208.000000   208.649994  805600.000000
#
#
# Statistics for PJP_df:
#               Open         High          Low        Close        Volume
# count  3000.000000  3000.000000  3000.000000  3000.000000  3.000000e+03
# mean     64.056187    64.475907    63.600410    64.060320  8.560467e+04
# std      12.887649    12.967454    12.827864    12.896328  1.119981e+05
# min      30.200001    30.530001    28.500000    30.180000  1.100000e+03
# 25%      58.997500    59.407500    58.509998    58.980000  1.660000e+04
# 50%      65.185001    65.540001    64.709999    65.155003  4.535000e+04
# 75%      74.992498    75.512501    74.572500    75.057503  1.206500e+05
# max      83.589996    84.110001    83.339996    83.540001  2.469000e+06

# %%
# check starting date is January 6th, 2020
for df_name, df in dfs.items():
    print(f"Starting date for {df_name}: {df.index[0]}")
    print("\n")
# Out:
# Starting date for LLY_df: 2012-03-27 00:00:00
#
#
# Starting date for NVO_df: 2012-03-27 00:00:00
#
#
# Starting date for JNJ_df: 2012-03-27 00:00:00
#
#
# Starting date for MRK_df: 2012-03-27 00:00:00
#
#
# Starting date for ABBV_df: 2013-01-02 00:00:00
#
#
# Starting date for MRNA_df: 2018-12-07 00:00:00
#
#
# Starting date for NVS_df: 2012-03-27 00:00:00
#
#
# Starting date for AZN_df: 2012-03-27 00:00:00
#
#
# Starting date for PFE_df: 2012-03-27 00:00:00
#
#
# Starting date for AMGN_df: 2012-03-27 00:00:00
#
#
# Starting date for PPH_df: 2012-03-27 00:00:00
#
#
# Starting date for IHE_df: 2012-03-27 00:00:00
#
#
# Starting date for PJP_df: 2012-03-27 00:00:00

# %%
# export dataframes to /pharma-data/clean-data/stocks
for df_name, df in dfs.items():
    df.to_csv(f"pharma-data/clean-data/stocks-for-overdose/{df_name}.csv")
